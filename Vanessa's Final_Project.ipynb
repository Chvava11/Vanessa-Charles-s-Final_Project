# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# A young entrepreneur who made handmade jewelries and sandals in Haiti, the name of her company is LOV’ART. In Haiti it’s easy to sell product and the customers love them, often she found people who live in others countries who want to buy LOVE’ART’s products sometimes it is very difficult to find the opportunity to sell the product in the international market, she would like to analyze some states in some countries to find a better place to open a LOV’ART store so she can sell the products easily and also enhance Haitian production at the international level.

# %% [markdown]
# # Introduction: Business Problem
# In this project we will try to find an optimal location to open a store who made handmade jewelries and sandals in USA or Canada. Specifically, this report will be targeted other entrepreneur who would like to expand their business in the international market can be interest.

# %% [markdown]
# # DATA
# number of existing jewelleries in the neighborhood (any type of jewelleries)

# %%
#import the libraries 
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import os # accessing directory structure

# %%
# read the file and assign it to the variable "df_toronto"
df_toronto = pd.read_csv('MCI_2014_to_2019 (1).csv')
df_toronto.head()
# Out:
#               X             Y  Index_ event_unique_id          occurrencedate  \
# 0 -8.816401e+06  5.434587e+06     701  GO-20141756319  2014/03/24 00:00:00+00
# 1 -8.837252e+06  5.413357e+06     901  GO-20143006885  2014/09/27 00:00:00+00
# 2 -8.862433e+06  5.422276e+06     702  GO-20141756802  2014/03/24 00:00:00+00
# 3 -8.833104e+06  5.431887e+06     703  GO-20141760570  2014/03/24 00:00:00+00
# 4 -8.845311e+06  5.413667e+06     902  GO-20142004859  2014/05/03 00:00:00+00
#
#              reporteddate premisetype  ucr_code  ucr_ext             offence  \
# 0  2014/03/24 00:00:00+00  Commercial      1430      100             Assault
# 1  2014/09/29 00:00:00+00       Other      2120      200                 B&E
# 2  2014/03/24 00:00:00+00  Commercial      2120      200                 B&E
# 3  2014/03/24 00:00:00+00   Apartment      2120      200                 B&E
# 4  2014/05/03 00:00:00+00  Commercial      1610      210  Robbery - Business
#
# ...

# %%
df_houses = pd.read_csv('houses.csv') 
df_houses.head()
# Out:
#    index                                              title  final_price  \
# 0      0  1303 - 38 Grenville St, Toronto (C4461599) | Z...       855000
# 1      1          2 Cabot Crt, Toronto (W4502992) | Zoocasa       885000
# 2      2  1504 - 30 Roehampton Ave, Toronto (C4511330) |...       550000
# 3      3  514 - 65 East Liberty St, Toronto (C4515763) |...       665000
# 4      4        61 Twelfth St, Toronto (W4519375) | Zoocasa       825513
#
#    list_price    bedrooms bathrooms             sqft     parking  \
# 0      870000  2 + 1 beds   2 baths  800–899 sq. ft.   1 parking
# 1      898000      3 beds   2 baths      N/A sq. ft.   6 parking
# 2      549900      1 beds   1 baths  500–599 sq. ft.  no parking
# 3      600000  1 + 1 beds   1 baths  600–699 sq. ft.   1 parking
# 4      839000      2 beds   2 baths      N/A sq. ft.   1 parking
#
#                                          description       mls           type  \
# ...

# %%
df_toronto.head()
# Out:
#               X             Y  Index_ event_unique_id          occurrencedate  \
# 0 -8.816401e+06  5.434587e+06     701  GO-20141756319  2014/03/24 00:00:00+00
# 1 -8.837252e+06  5.413357e+06     901  GO-20143006885  2014/09/27 00:00:00+00
# 2 -8.862433e+06  5.422276e+06     702  GO-20141756802  2014/03/24 00:00:00+00
# 3 -8.833104e+06  5.431887e+06     703  GO-20141760570  2014/03/24 00:00:00+00
# 4 -8.845311e+06  5.413667e+06     902  GO-20142004859  2014/05/03 00:00:00+00
#
#              reporteddate premisetype  ucr_code  ucr_ext             offence  \
# 0  2014/03/24 00:00:00+00  Commercial      1430      100             Assault
# 1  2014/09/29 00:00:00+00       Other      2120      200                 B&E
# 2  2014/03/24 00:00:00+00  Commercial      2120      200                 B&E
# 3  2014/03/24 00:00:00+00   Apartment      2120      200                 B&E
# 4  2014/05/03 00:00:00+00  Commercial      1610      210  Robbery - Business
#
# ...

# %%
df_toronto.rename(columns = {'offence':'type of crime'}, inplace = True)

# %%
#type of each variables 
df_toronto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206435 entries, 0 to 206434
# Data columns (total 29 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   X                    206435 non-null  float64
#  1   Y                    206435 non-null  float64
#  2   Index_               206435 non-null  int64
#  3   event_unique_id      206435 non-null  object
#  4   occurrencedate       206435 non-null  object
#  5   reporteddate         206435 non-null  object
#  6   premisetype          206435 non-null  object
#  7   ucr_code             206435 non-null  int64
#  8   ucr_ext              206435 non-null  int64
#  9   type of crime        206435 non-null  object
#  10  reportedyear         206435 non-null  int64
#  11  reportedmonth        206435 non-null  object
#  12  reportedday          206435 non-null  int64
#  13  reporteddayofyear    206435 non-null  int64
#  14  reporteddayofweek    206435 non-null  object
# ...

# %%
df_toronto.shape
# Out:
# (206435, 29)

# %%
df_toronto.isnull().sum(axis=0)
# Out:
# X                       0
# Y                       0
# Index_                  0
# event_unique_id         0
# occurrencedate          0
# reporteddate            0
# premisetype             0
# ucr_code                0
# ucr_ext                 0
# type of crime           0
# reportedyear            0
# reportedmonth           0
# reportedday             0
# reporteddayofyear       0
# reporteddayofweek       0
# reportedhour            0
# occurrenceyear         59
# occurrencemonth        59
# occurrenceday          59
# occurrencedayofyear    59
# occurrencedayofweek    59
# occurrencehour          0
# MCI                     0
# Division                0
# Hood_ID                 0
# Neighbourhood           0
# Long                    0
# Lat                     0
# ObjectId                0
# dtype: int64

# %%
df_toronto
# Out:
#                    X             Y  Index_ event_unique_id  \
# 0      -8.816401e+06  5.434587e+06     701  GO-20141756319
# 1      -8.837252e+06  5.413357e+06     901  GO-20143006885
# 2      -8.862433e+06  5.422276e+06     702  GO-20141756802
# 3      -8.833104e+06  5.431887e+06     703  GO-20141760570
# 4      -8.845311e+06  5.413667e+06     902  GO-20142004859
# ...              ...           ...     ...             ...
# 206430 -8.862292e+06  5.420779e+06  206431  GO-20192475076
# 206431 -8.856234e+06  5.405305e+06  206432  GO-20192479140
# 206432 -8.836031e+06  5.414712e+06  206433  GO-20192495839
# 206433 -8.849676e+06  5.419234e+06  206434  GO-20192476502
# 206434 -8.848457e+06  5.414238e+06  206435  GO-20192476230
#
#                 occurrencedate            reporteddate premisetype  ucr_code  \
# 0       2014/03/24 00:00:00+00  2014/03/24 00:00:00+00  Commercial      1430
# 1       2014/09/27 00:00:00+00  2014/09/29 00:00:00+00       Other      2120
# ...

# %%
df_toronto.dropna(inplace=True,axis=0)

# %%
df_toronto.isnull().sum(axis=0)
# Out:
# X                      0
# Y                      0
# Index_                 0
# event_unique_id        0
# occurrencedate         0
# reporteddate           0
# premisetype            0
# ucr_code               0
# ucr_ext                0
# type of crime          0
# reportedyear           0
# reportedmonth          0
# reportedday            0
# reporteddayofyear      0
# reporteddayofweek      0
# reportedhour           0
# occurrenceyear         0
# occurrencemonth        0
# occurrenceday          0
# occurrencedayofyear    0
# occurrencedayofweek    0
# occurrencehour         0
# MCI                    0
# Division               0
# Hood_ID                0
# Neighbourhood          0
# Long                   0
# Lat                    0
# ObjectId               0
# dtype: int64

# %%
df_toronto.mean
# Out:
# <bound method DataFrame.mean of                    X             Y  Index_ event_unique_id  \
# 0      -8.816401e+06  5.434587e+06     701  GO-20141756319
# 1      -8.837252e+06  5.413357e+06     901  GO-20143006885
# 2      -8.862433e+06  5.422276e+06     702  GO-20141756802
# 3      -8.833104e+06  5.431887e+06     703  GO-20141760570
# 4      -8.845311e+06  5.413667e+06     902  GO-20142004859
# ...              ...           ...     ...             ...
# 206430 -8.862292e+06  5.420779e+06  206431  GO-20192475076
# 206431 -8.856234e+06  5.405305e+06  206432  GO-20192479140
# 206432 -8.836031e+06  5.414712e+06  206433  GO-20192495839
# 206433 -8.849676e+06  5.419234e+06  206434  GO-20192476502
# 206434 -8.848457e+06  5.414238e+06  206435  GO-20192476230
#
#                 occurrencedate            reporteddate premisetype  ucr_code  \
# 0       2014/03/24 00:00:00+00  2014/03/24 00:00:00+00  Commercial      1430
# ...

# %%
df_toronto.describe()
# Out:
#                   X             Y         Index_       ucr_code  \
# count  2.063760e+05  2.063760e+05  206376.000000  206376.000000
# mean  -8.838205e+06  5.420273e+06  103225.154325    1696.718964
# std    1.161969e+04  8.119243e+03   59588.472658     323.491149
# min   -8.865403e+06  5.401765e+06       1.000000    1410.000000
# 25%   -8.846725e+06  5.413154e+06   51623.750000    1430.000000
# 50%   -8.838025e+06  5.419338e+06  103226.500000    1450.000000
# 75%   -8.829811e+06  5.427154e+06  154825.250000    2120.000000
# max   -8.807943e+06  5.442380e+06  206435.000000    2135.000000
#
#              ucr_ext   reportedyear    reportedday  reporteddayofyear  \
# count  206376.000000  206376.000000  206376.000000      206376.000000
# mean      145.982978    2016.619534      15.746967         187.150173
# std        51.740956       1.717656       8.770544         103.599033
# min       100.000000    2014.000000       1.000000           1.000000
# ...

# %%
df_toronto.nunique()
# Out:
# X                       15352
# Y                       15259
# Index_                 206376
# event_unique_id        179765
# occurrencedate           2544
# reporteddate             2191
# premisetype                 5
# ucr_code                   21
# ucr_ext                    16
# type of crime              49
# reportedyear                6
# reportedmonth              12
# reportedday                31
# reporteddayofyear         366
# reporteddayofweek           7
# reportedhour               24
# occurrenceyear             20
# occurrencemonth            12
# occurrenceday              31
# occurrencedayofyear       366
# occurrencedayofweek         7
# occurrencehour             24
# MCI                         5
# Division                   17
# Hood_ID                   140
# Neighbourhood             140
# Long                    15352
# Lat                     15259
# ObjectId               206376
# dtype: int64

# %%
df_toronto.count()
# Out:
# X                      206376
# Y                      206376
# Index_                 206376
# event_unique_id        206376
# occurrencedate         206376
# reporteddate           206376
# premisetype            206376
# ucr_code               206376
# ucr_ext                206376
# type of crime          206376
# reportedyear           206376
# reportedmonth          206376
# reportedday            206376
# reporteddayofyear      206376
# reporteddayofweek      206376
# reportedhour           206376
# occurrenceyear         206376
# occurrencemonth        206376
# occurrenceday          206376
# occurrencedayofyear    206376
# occurrencedayofweek    206376
# occurrencehour         206376
# MCI                    206376
# Division               206376
# Hood_ID                206376
# Neighbourhood          206376
# Long                   206376
# Lat                    206376
# ObjectId               206376
# dtype: int64

# %%
df_toronto['Neighbourhood'] =df_toronto['Neighbourhood'].apply(lambda x : x.split('(')[0])

# %%
df_toronto
# Out:
#                    X             Y  Index_ event_unique_id  \
# 0      -8.816401e+06  5.434587e+06     701  GO-20141756319
# 1      -8.837252e+06  5.413357e+06     901  GO-20143006885
# 2      -8.862433e+06  5.422276e+06     702  GO-20141756802
# 3      -8.833104e+06  5.431887e+06     703  GO-20141760570
# 4      -8.845311e+06  5.413667e+06     902  GO-20142004859
# ...              ...           ...     ...             ...
# 206430 -8.862292e+06  5.420779e+06  206431  GO-20192475076
# 206431 -8.856234e+06  5.405305e+06  206432  GO-20192479140
# 206432 -8.836031e+06  5.414712e+06  206433  GO-20192495839
# 206433 -8.849676e+06  5.419234e+06  206434  GO-20192476502
# 206434 -8.848457e+06  5.414238e+06  206435  GO-20192476230
#
#                 occurrencedate            reporteddate premisetype  ucr_code  \
# 0       2014/03/24 00:00:00+00  2014/03/24 00:00:00+00  Commercial      1430
# 1       2014/09/27 00:00:00+00  2014/09/29 00:00:00+00       Other      2120
# ...

# %%
df_toronto['occurrencedayofyear'].value_counts()
# Out:
# 1.0      1423
# 305.0     881
# 182.0     869
# 152.0     817
# 244.0     813
#          ...
# 63.0      442
# 3.0       435
# 4.0       419
# 360.0     410
# 366.0      97
# Name: occurrencedayofyear, Length: 366, dtype: int64

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'HILLROI2XDCJI0CQZIFMQDAAZ3BCPHVYDECVDS010DZGAI5F' # your Foursquare ID
CLIENT_SECRET = 'LNLGG5U3QV5IWQ21GX2J0UZZXH2WD2EZUWH52A3S2KTWMUSA'

# your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: HILLROI2XDCJI0CQZIFMQDAAZ3BCPHVYDECVDS010DZGAI5F
# CLIENT_SECRET:LNLGG5U3QV5IWQ21GX2J0UZZXH2WD2EZUWH52A3S2KTWMUSA

# %%
long,lat =[],[]
for neigh in df_toronto['Neighbourhood']:
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(neigh+str(",Ontario"))
    if location:
        latitude = location.latitude
        longitude = location.longitude
        print(latitude, longitude)
# Out:
# 43.8091955 -79.2217008
# 43.6673421 -79.3884571
# 43.7926732 -79.3547219
# 43.6654775 -79.470352
# 43.7689144 -79.1872905
# 43.6654775 -79.470352
# 43.6901578 -79.4749985
# 43.7064433 -79.4526856
# 43.6654775 -79.470352
# 43.8033965 -79.25756324844703
# 43.897022 -78.85919806512936
# 43.6694032 -79.3727041
# 43.6514426 -79.4510381
# 43.7587808 -79.5194336
# 43.645335 -79.5248163
# 45.1809266 -75.3329018
# 43.6534465 -79.4002002
# 48.437712 -89.22802176678171
# 43.8091955 -79.2217008
# 43.7587808 -79.5194336
# 43.7587808 -79.5194336
# 43.7587808 -79.5194336
# 43.897022 -78.85919806512936
# 43.6903876 -79.3832965
# 43.897022 -78.85919806512936
# 43.897022 -78.85919806512936
# 43.897022 -78.85919806512936
# 43.897022 -78.85919806512936
# 43.897022 -78.85919806512936
# 43.897022 -78.85919806512936
# 43.6673421 -79.3884571
# 43.6703377 -79.407117
# 43.6703377 -79.407117
# 43.6703377 -79.407117
# 43.7598243 -79.2252908
# 43.7572532 -79.5176975
# 48.437712 -89.22802176678171
# ...

# %%
import
